# %%
import ollama
from langchain_docling.loader import DoclingLoader
model="llama3:8b"
FILE_PATH=r"C:\Users\anany\Desktop\PANTULA ANANYA genc.pdf"
loader=DoclingLoader(file_path=FILE_PATH)
docs=loader.load()
# Out:
# ...
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-06-18 14:20:47,977 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-06-18 14:20:48,083 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-18 14:20:48,086 [RapidOCR] main.py:65: Using C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-18 14:20:48,802 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# ...

# %%
from docling.document_converter import (
    DocumentConverter,
    PdfFormatOption
)

from docling. datamodel.base_models import InputFormat
from docling. datamodel.pipeline_options import PdfPipelineOptions

# Configure PDF processing
pipeline_options = PdfPipelineOptions()

# Extract images
pipeline_options.generate_picture_images = True
pipeline_options.generate_page_images = True

# Create converter
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options
        )
    }
)

# Convert PDF
result = converter.convert(FILE_PATH)

# Get document
doc = result.document
# Out:
# [INFO] 2026-06-18 14:21:05,441 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-06-18 14:21:05,464 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-18 14:21:05,468 [RapidOCR] main.py:65: Using C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-18 14:21:05,945 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-06-18 14:21:05,952 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-06-18 14:21:05,954 [RapidOCR] main.py:65: Using C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# ...

# %%
print(len(doc.pictures))
# Out:
# 1

# %%
from docling.chunking import HybridChunker
chunker = HybridChunker()
chunks = list(chunker.chunk(dl_doc=doc))

# %%
# !pip install google-generativeai
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\anany\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
IMAGE_PROMPT = """
Generate a comprehensive semantic description of this image for use in a multimodal retrieval system.

Describe all visible content including:
- Titles and headings
- Objects and entities
- Text and numbers
- Tables and charts
- Axes, legends and units
- Diagrams and flowcharts
- Relationships between components
- Colors and layout when important
- Statistics and measurements
- Technical terminology
- Key conclusions and insights

Preserve names, dates, values, and identifiers exactly.

Produce a detailed, self-contained description so that a user can answer questions about the image without directly seeing it.

Return only the description.
"""

# %%
def summarize_image(image):

    response = model.generate_content(
        [
            IMAGE_PROMPT,
            image
        ]
    )

    print(response.text)

    return response.text

# %%
documents = []
from langchain_core.documents import Document

# %%
def summarize_chunk(text):
    # Your summarization logic (or LLM call) goes here
    return f"Summary of: {text[:20]}..."

# %%
from langchain_core.documents import Document

documents = []

for chunk in chunks:
    print("chunked")
    summary = summarize_chunk(str(chunk.text))

    documents. append(
        Document(
            page_content=summary,
            metadata={
                "type": "text"
            }
        )
    )
# Out:
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked
# chunked

# %%
import google. generativeai as genai
genai.configure(api_key="**********")
model = genai.GenerativeModel('gemini-2.5-flash')
IMAGE_PROMPT = "Describe this image in detail for a document summary."

# %%
# Add images
for picture in doc.pictures:

    image = picture.get_image(doc)

    if image is None:
        continue

    summary = summarize_image(image)

    documents.append(
        Document(
            page_content=summary,
            metadata={
                "type": "image"
            }
        )
    )
# Out:
# This is a professionally taken headshot or portrait-style photograph featuring a young adult woman of medium complexion.
#
# She is positioned centrally in the frame, facing directly towards the viewer with a neutral, professional demeanor and a gentle, closed-mouth smile. Her dark hair is neatly pulled back from her face, exposing her forehead and ears, and appears to be styled off her shoulders.
#
# She is wearing dark, rectangular-framed prescription glasses that sit across the bridge of her nose. Her dark eyes are looking straight ahead, and her eyebrows are well-defined.
#
# Her attire consists of business professional clothing: a dark navy blue blazer or suit jacket worn over a crisp white collared shirt. No tie or other prominent accessories are visible.
#
# ...

# %%
len(documents)
# Out:
# 12

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="mixedbread-ai/mxbai-embed-large-v1",
)
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
from langchain_chroma import Chroma

vectorstore = Chroma(
    collection_name="multimodal_rag",
    persist_directory="./chroma_mragdb",
    embedding_function=embeddings
)

# %%
vectorstore._collection.count()
# Out:
# 24

# %%
vectorstore.add_documents(documents)
# Out:
# ['14ecdd15-f7f5-45b3-abfc-90de24793188',
#  '0f427d95-5f70-4f76-9a46-4355bb7c20cb',
#  '08781115-83e8-43a5-8303-3579a1550972',
#  'e1827253-c059-4050-ac32-0c393676d384',
#  'a9d72c19-006c-4bc7-96ab-00afb3b6fc73',
#  'a4d78eee-e5a3-498f-be28-8d0148c7a1c0',
#  '60023b59-3864-40cd-a69f-2742b94008c6',
#  'a0c58e28-59a0-4526-bdea-d29ab4c979fb',
#  '7320fc2f-b81a-41a7-a836-c922511345ae',
#  'c1186615-9cb4-4ccb-90eb-947589854b03',
#  'a9743b37-7a1e-4001-a87d-74c4956f6c8c',
#  '86cc305c-366a-4f78-9a90-61d4bfde3b97']

# %%
vectorstore._collection.count()
# Out:
# 36

# %%
retriever = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={
        "k":20,
        "fetch_k":50
    }
)

# %%
from sentence_transformers import CrossEncoder

reranker = CrossEncoder(
    "BAAI/bge-reranker-large",
)
# Out:
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]

# %%
def retrieve(query, top_k=5):

    docs = retriever.invoke(query)

    pairs = [
        [query, doc.page_content]
        for doc in docs
    ]

    scores = reranker.predict(pairs)

    ranked_docs = sorted(
        zip(scores, docs),
        key=lambda x: x[0],
        reverse=True
    )

    return [
        doc
        for score, doc in ranked_docs[:top_k]
    ]

# %%
def build_context(query):

    retrieved_docs = retrieve(query)

    context = "\n\n".join(
        doc.page_content
        for doc in retrieved_docs
    )

    return context

# %%
import requests

def generate_response(prompt):

    response = requests.post(
        "https://requestspost.ananyaanu151.workers.dev/",
        headers={
            "Authorization": "Bearer 123456789",
            "Content-Type": "application/json"
        },
        json={
            "prompt": prompt
        }
    )

    return response.json()

# %%
def ask(query):

    context = build_context(query)
    print(f"The context retrived is:{context}")

    prompt = f"""
You are a helpful assistant.

Answer the question using ONLY the context below.

If the answer is not present, say:
'I could not find the answer in the provided context.'

Context:
{context}

Question:
{query}

Answer:
"""

    return generate_response(prompt)

# %%
answer = ask(
    "What are the skills that give me in a single line"
)

print(answer)
# Out:
# The context retrived is:Summary of: - Leadership -Experi...
#
# Summary of: - Strong team player...
#
# Summary of: - Strong team player...
#
# Summary of: - Strong team player...
#
# Summary of: - •
# - Programming La...
# {'error': 'Unauthorized'}

# %%
from transformers import AutoTokenizer
from docling.chunking import HybridChunker

tokenizer = AutoTokenizer.from_pretrained(
    "sentence-transformers/all-MiniLM-L6-v2"
)

# %%
chunker = HybridChunker(
    tokenizer=tokenizer,
    max_tokens=1024
)

chunks = list(chunker.chunk(dl_doc=doc))

# %%
len(chunks)
# Out:
# 11

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter


splitter = RecursiveCharacterTextSplitter(
    chunk_size=3000,
    chunk_overlap=600
)

docs = []

for chunk in chunks:
    docs.extend(
        splitter.create_documents(
            [chunk.text]
        )
    )

# %%
len(docs)
# Out:
# 11

# %%
docs[0]
# Out:
# Document(metadata={}, page_content='linkedin.com/in/ananya-pantula-910112221/\n+91 8499811978\nananyaanu151@gmail.com\nLinkedIn:\nEmail:\nPhone:')

# %%
import requests

# Your live Cloudflare Worker URL
WORKER_URL = "https://requestspost.ananyaanu151.workers.dev/"

# The Authorization Key required by your code ("123456789")
API_KEY = "123456789"

# Configure headers mirroring your Worker's validation rules
headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

# The payload data containing your prompt
data_payload = {
    "prompt": "What are the core differences between Llama 3.3 and Journey 2.5?",
    "systemPrompt": "You are a helpful and knowledgeable AI assistant.",
    "history": []
}

try:
    print("Sending request to your live Cloudflare Worker...")
    
    # Make the POST request to your endpoint
    response = requests.post(WORKER_URL, headers=headers, json=data_payload)
    
    # Check the output status and parse JSON
    print(f"HTTP Status Code: {response.status_code}")
    print("--- Response Output ---")
    print(response.json())

except Exception as e:
    print(f"An error occurred while connecting to the worker: {e}")
# Out:
# Sending request to your live Cloudflare Worker...
# HTTP Status Code: 401
# --- Response Output ---
# {'error': 'Unauthorized'}
